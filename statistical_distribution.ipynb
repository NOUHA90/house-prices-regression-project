# %% [markdown]
# # **House Prices - Advanced Regression Techniques**

# %%
from IPython.display import Image
Image('housesbanner.png')

# %%
from data import Data
dataframe = Data()

# %%
house_prices_data = dataframe.read_original_data('house_prices_cleaned_data.csv')
house_prices_data = house_prices_data.drop(columns=['Unnamed: 0'])
house_prices_data.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1460.0      70.049958     22.024023     21.0      60.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1460.0     103.117123    180.731373      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %% [markdown]
# ## ** Histogrames continues Variables **

# %%
dataframe.plot_variable_histograme('LotFrontage', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  LotFrontage
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean       70.049958
# std        22.024023
# min        21.000000
# 25%        60.000000
# 50%        70.049958
# 75%        79.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
dataframe.plot_variable_histograme('LotArea', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  LotArea
# -------------------------------------------------------------------------------
#
#
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
dataframe.plot_variable_histograme('BsmtUnfSF', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  BsmtUnfSF
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean      567.240411
# std       441.866955
# min         0.000000
# 25%       223.000000
# 50%       477.500000
# 75%       808.000000
# max      2336.000000
# Name: BsmtUnfSF, dtype: float64

# %%
dataframe.plot_variable_histograme('TotalBsmtSF', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  TotalBsmtSF
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean     1057.429452
# std       438.705324
# min         0.000000
# 25%       795.750000
# 50%       991.500000
# 75%      1298.250000
# max      6110.000000
# Name: TotalBsmtSF, dtype: float64

# %%
dataframe.plot_variable_histograme('1stFlrSF', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  1stFlrSF
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean     1162.626712
# std       386.587738
# min       334.000000
# 25%       882.000000
# 50%      1087.000000
# 75%      1391.250000
# max      4692.000000
# Name: 1stFlrSF, dtype: float64

# %%
dataframe.plot_variable_histograme('GarageArea', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  GarageArea
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean      472.980137
# std       213.804841
# min         0.000000
# 25%       334.500000
# 50%       480.000000
# 75%       576.000000
# max      1418.000000
# Name: GarageArea, dtype: float64

# %%
dataframe.plot_variable_histograme('GrLivArea', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  GrLivArea
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean     1515.463699
# std       525.480383
# min       334.000000
# 25%      1129.500000
# 50%      1464.000000
# 75%      1776.750000
# max      5642.000000
# Name: GrLivArea, dtype: float64

# %%
dataframe.plot_variable_histograme('SalePrice', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  SalePrice
# -------------------------------------------------------------------------------
#
#
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## ** Histogrames discontinues Variables **

# %%
dataframe.histoplot_discontinued_variables('MSSubClass', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  MSSubClass
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean       56.897260
# std        42.300571
# min        20.000000
# 25%        20.000000
# 50%        50.000000
# 75%        70.000000
# max       190.000000
# Name: MSSubClass, dtype: float64

# %%
dataframe.histoplot_discontinued_variables('MSZoning', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  MSZoning
# -------------------------------------------------------------------------------
#
#
# count     1460
# unique       5
# top         RL
# freq      1151
# Name: MSZoning, dtype: object

# %%
dataframe.histoplot_discontinued_variables('Street', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  Street
# -------------------------------------------------------------------------------
#
#
# count     1460
# unique       2
# top       Pave
# freq      1454
# Name: Street, dtype: object

# %%
dataframe.histoplot_discontinued_variables('LotShape', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  LotShape
# -------------------------------------------------------------------------------
#
#
# count     1460
# unique       4
# top        Reg
# freq       925
# Name: LotShape, dtype: object

# %%
dataframe.histoplot_discontinued_variables('LandContour', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  LandContour
# -------------------------------------------------------------------------------
#
#
# count     1460
# unique       4
# top        Lvl
# freq      1311
# Name: LandContour, dtype: object

# %%
dataframe.histoplot_discontinued_variables('Utilities', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  Utilities
# -------------------------------------------------------------------------------
#
#
# count       1460
# unique         2
# top       AllPub
# freq        1459
# Name: Utilities, dtype: object

# %%
dataframe.histoplot_discontinued_variables('LotConfig', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  LotConfig
# -------------------------------------------------------------------------------
#
#
# count       1460
# unique         5
# top       Inside
# freq        1052
# Name: LotConfig, dtype: object

# %%
dataframe.histoplot_discontinued_variables('OverallQual', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  OverallQual
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean        6.099315
# std         1.382997
# min         1.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: OverallQual, dtype: float64

# %%
dataframe.histoplot_discontinued_variables('OverallCond', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  OverallCond
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean        5.575342
# std         1.112799
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%         6.000000
# max         9.000000
# Name: OverallCond, dtype: float64

# %%
dataframe.histoplot_discontinued_variables('YearBuilt', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  YearBuilt
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean     1971.267808
# std        30.202904
# min      1872.000000
# 25%      1954.000000
# 50%      1973.000000
# 75%      2000.000000
# max      2010.000000
# Name: YearBuilt, dtype: float64

# %%
dataframe.histoplot_discontinued_variables('TotRmsAbvGrd', house_prices_data)
# Out:
# -------------------------------------------------------------------------------
# The histograme of the Statistical distribution of  TotRmsAbvGrd
# -------------------------------------------------------------------------------
#
#
# count    1460.000000
# mean        6.517808
# std         1.625393
# min         2.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        14.000000
# Name: TotRmsAbvGrd, dtype: float64
